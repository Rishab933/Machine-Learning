# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df = df.iloc[:,2:]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 14    18            82000          0
# 349   38            61000          0
# 313   49           141000          1
# 351   37            75000          0
# 250   44            39000          0

# %% [markdown]
# # **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1)
                                                    , df['Purchased'], test_size =0.3, random_state=0)

# %%
x_train.shape, x_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# # **StandardScaler**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(x_train)
# this will cal the mean of both the columns passed and standard deviation also.
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
scaler.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
# This x_tain_scaled is a numpy array and not a pandas data frame
x_train_scaled
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
# ...

# %%
x_train_scaled = pd.DataFrame(x_train_scaled,columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled,columns = x_test.columns)

# %%
x_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %%
np.round(x_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %% [markdown]
# # **Effect of Scaling**

# %%
# This will give me 2 graphs
fig, (ax1, ax2)= plt.subplots(ncols=2, figsize=(12,5))

# plotting x_train in the first graph
ax1.scatter(x_train['Age'], x_train['EstimatedSalary'])
ax1.set_title("Before Scaling")

# plotting x_train_scaled in the second graph
ax2.scatter(x_train_scaled['Age'], x_train_scaled['EstimatedSalary'])
ax2.set_title("After Scaling")

plt.show()

# %% [markdown]
# # **PDF Before and After Scaling**

# %%
# This will give me 2 graphs
fig, (ax1, ax2)= plt.subplots(ncols=2, figsize=(12,5))

# plotting x_train in the first graph
ax1.set_title("Before Scaling")
sns.kdeplot(x_train['Age'], ax=ax1)
sns.kdeplot(x_train['EstimatedSalary'],ax=ax1)

# plotting x_train_scaled in the second graph
ax2.set_title("After Scaling")
sns.kdeplot(x_train_scaled['Age'], ax=ax2)
sns.kdeplot(x_train_scaled['EstimatedSalary'],ax=ax2)

plt.show()

# %% [markdown]
# # **Comparison of Distribution**

# %%
# This will give me 2 graphs
fig, (ax1, ax2)= plt.subplots(ncols=2, figsize=(12,5))

# plotting x_train in the first graph
ax1.set_title("Before Scaling")
sns.kdeplot(x_train['Age'], ax=ax1)

# plotting x_train_scaled in the second graph
ax2.set_title("After Scaling")
sns.kdeplot(x_train_scaled['Age'], ax=ax2)

plt.show()

# %%
# This will give me 2 graphs
fig, (ax1, ax2)= plt.subplots(ncols=2, figsize=(12,5))

# plotting x_train in the first graph
ax1.set_title("Before Scaling")
sns.kdeplot(x_train['EstimatedSalary'], ax=ax1)

# plotting x_train_scaled in the second graph
ax2.set_title("After Scaling")
sns.kdeplot(x_train_scaled['EstimatedSalary'], ax=ax2)

plt.show()

# %% [markdown]
# # **Why Scaling is Important?**

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(x_train,y_train)
lr_scaled.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)
y_pred_scaled = lr_scaled.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual", accuracy_score(y_test, y_pred))
print("Scaled", accuracy_score(y_test, y_pred_scaled))
# Out:
# Actual 0.6583333333333333
# Scaled 0.8666666666666667

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
dt_scaled.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)
y_pred_scaled = dt_scaled.predict(x_test_scaled)

# %%
print("Actual", accuracy_score(y_test, y_pred))
print("Scaled", accuracy_score(y_test, y_pred_scaled))
# Out:
# Actual 0.875
# Scaled 0.875

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# # **Effect of Outlier**

# %%
new_data = pd.DataFrame({
    'Age': [5, 90, 95],
    'EstimatedSalary': [1000, 250000, 350000],
    'Purchased': [0, 1, 1]
})

# %%
df = pd.concat([df, new_data], ignore_index=True)

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 398   36            33000          0
# 399   49            36000          1
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
#
# [403 rows x 3 columns]

# %%
plt.scatter(df['Age'], df['EstimatedSalary'])

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1)
                                                    , df['Purchased'], test_size =0.3, random_state=0)

# %%
x_train.shape, x_test.shape
# Out:
# ((282, 2), (121, 2))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(x_train)
# this will cal the mean of both the columns passed and standard deviation also.
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled = pd.DataFrame(x_train_scaled,columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled,columns = x_test.columns)

# %%
np.round(x_train.describe(),1)
np.round(x_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  282.0            282.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -3.0             -1.9
# 25%     -0.7             -0.7
# 50%     -0.1             -0.0
# 75%      0.7              0.5
# max      4.7              5.1

# %%
# This will give me 2 graphs
fig, (ax1, ax2)= plt.subplots(ncols=2, figsize=(12,5))

# plotting x_train in the first graph
ax1.scatter(x_train['Age'], x_train['EstimatedSalary'])
ax1.set_title("Before Scaling")

# plotting x_train_scaled in the second graph
ax2.scatter(x_train_scaled['Age'], x_train_scaled['EstimatedSalary'])
ax2.set_title("After Scaling")

plt.show()

# %% [markdown]
# The effect of outliers is not reduced.
#
# we have to reduce it explicitly.
