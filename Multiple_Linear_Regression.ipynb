# %%
# Multiple Linear Regression is for multiple inputs
# This mean taking multiple input columns and then predicting an output

# make_regression --> this is a function of sklearn used to generate n dimenssional
# linear dataset which can be used in any linear model
# x,y = make_regression(n_samples=(number of rows),n_features=(number of col),n_informative=(number of col used for prediction),n_target=(number of output),noise=(random))

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
x,y = make_regression(n_samples=1000,n_features=2,n_informative=2,n_targets=1,noise=50)

# %%
df = pd.DataFrame({'feature1':x[:,0],'feature2':x[:,1],'target':y})

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0 -0.232211  0.531414  55.600042
# 1 -0.888940  1.005630   6.079011
# 2  2.077086  0.545163  65.187645
# 3 -0.481038  0.333599  13.864762
# 4 -0.478114 -0.517968 -86.351257

# %%
df.shape
# Out:
# (1000, 3)

# %%
fig = px.scatter_3d(df,x='feature1',y='feature2',z='target')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
print("MAE = ",mean_absolute_error(y_test,y_pred))
print("MSE = ",mean_squared_error(y_test,y_pred))
print("R2_score = ",r2_score(y_test,y_pred))
# Out:
# MAE =  48.22760690766094
# MSE =  3531.6562767974865
# R2_score =  0.5490876645417035
