# %%
import requests

url = "https://crypto-price-technical-indicators-signals.p.rapidapi.com/indicators/BTCUSDT"

headers = {
	"x-rapidapi-key": "4acd72e310msh1dea14c9db5869fp1e0a42jsn2f032e709ae5",
	"x-rapidapi-host": "crypto-price-technical-indicators-signals.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %%
import pandas as pd

# %%
df = pd.DataFrame(response.json())

# %%
df
# Out:
#                                                                1m  \
# RSI                                                         54.04
# MACD            {'MACD': -2.6440740257821744, 'signal': -9.916...
# KDJ             {'K': 85.0815850815822, 'D': 85.88741008095671...
# MA                                                   63931.435714
# BollingerBands  {'middle': 63916.88499999997, 'upper': 63970.2...
# VWAP                                                 64301.463651
#
#                                                                3m  \
# RSI                                                         46.52
# MACD            {'MACD': -32.20719230440591, 'signal': -32.825...
# KDJ             {'K': 56.559766763848394, 'D': 46.841593780369...
# MA                                                   63947.264286
# BollingerBands  {'middle': 63964.42, 'upper': 64057.7569294545...
# VWAP                                                 64163.219156
#
# ...

# %%
df = pd.DataFrame(response.json())[['15m','1h','1d','1w']]

# %%
df
# Out:
#                                                               15m  \
# RSI                                                         44.44
# MACD            {'MACD': -60.231743047595955, 'signal': -53.85...
# KDJ             {'K': 51.22881355932265, 'D': 44.5268361581924...
# MA                                                   64005.057143
# BollingerBands  {'middle': 64008.909999999974, 'upper': 64159....
# VWAP                                                 61887.111048
#
#                                                                1h  \
# RSI                                                         47.16
# MACD            {'MACD': 28.82040910829528, 'signal': 65.08445...
# KDJ             {'K': 16.520967080999913, 'D': 20.709830168920...
# MA                                                   64116.042857
# BollingerBands  {'middle': 64074.824999999975, 'upper': 64374....
# VWAP                                                 58678.659737
#
# ...

# %%
df.shape
# Out:
# (6, 4)

# %%
df.to_csv('BTC_Indicators')
